# %% [markdown]
# referência: https://dadosabertos.bcb.gov.br/dataset/estatisticas-meios-pagamentos
#
# ### Estatísticas de Meios de Pagamentos
#
#
# Este conjunto contém diversas estatísticas relacionadas a meios de pagamento. Atualmente está disponibilizado um recurso com informações sobre operações com cartões de pagamento, e outros 2 recursos com diversos instrumentos de pagamentos de varejo utilizados no país.
#
# Estão disponibilizadas estatísticas dos seguintes meios de pagamento:
#
# Instrumentos de periodicidade mensal, com atualização 17 dias após o final do mês de referência:
#
# Pix (fonte: SPI e documento 1201)
# TED (fonte: CIP-SITRAF e STR)
# Boletos (fonte: CIP-SILOC)
# DOC e TEC (fonte: CIP-SILOC)
# Cheque (fonte: Compe)
# Instrumentos de periodicidade trimestral, com atualização 2 meses após o final do trimestre de referência:
#
# Cartões de crédito, débito e pré-pagos (fonte: documentos 6308 e 6334)
# Pagamentos de convênio, saques, transferências intra-bancárias e débito direto (fonte: documento 6209)
# Serão disponibilizadas no futuro novos recursos relacionados a cartões de pagamentos, bem como canais de acesso utilizados em transações financeiras.
#
# Por fim, anualmente são publicadas em uma planilha eletrônica demais estatísticas de meios de pagamentos, acessíveis pelo recurso 'Site do BC - Estatísticas de Meios de Pagamento'.
#
# **Links Úteis:**
# - Documentação: https://dadosabertos.bcb.gov.br/dataset/estatisticas-meios-pagamentos/resource/87ba5557-228e-48ca-9682-348f2d4d9f11
# - Swagger ui2: https://olinda.bcb.gov.br/olinda/servico/MPV_DadosAbertos/versao/v1/swagger-ui2#/
# - Swagger ui3: https://olinda.bcb.gov.br/olinda/servico/MPV_DadosAbertos/versao/v1/swagger-ui3#/

# %% [markdown]
# #### Consumindo a API Diretamente

# %%
import requests
import json


trimestre = "1"
ano_mes = "2024-01"

url_base = "https://olinda.bcb.gov.br/olinda/servico/MPV_DadosAbertos/versao/v1/odata"

# Recurso: Quantidade de cartões emitidos e ativos e transações realizadas com este instrumento de pagamento.
endpoint_cartoes = f"{url_base}/Quantidadeetransacoesdecartoes(trimestre=@trimestre)?%40trimestre='{trimestre}'"

# Recurso: Informações sobre operações com boletos bancários e de transferências de crédito
endpoint_pagamentos_mensal= f"{url_base}/MeiosdePagamentosMensalDA(AnoMes=@AnoMes)?%40AnoMes='{ano_mes}'"

# Recurso: Quantidade de cartões emitidos e ativos e transações realizadas com este instrumento de pagamento.
endpoint_cartoes = f"{url_base}/MeiosdePagamentosTrimestralDA(trimestre=@trimestre)?%40trimestre='{trimestre}'"

header = {
    'Accept': 'application/json'

}

urll = endpoint_cartoes

try:
    
    response = requests.get(urll, headers = header)

    if response.status_code == 200:
    print(json.dumps(response.json(), indent=4, ensure_ascii= False))

except Exception as e:
    print(f"Erro ao realizar chamada ao recurso: {urll}, error: {e}")
# Out:
# {
#     "@odata.context": "https://was-p.bcnet.bcb.gov.br/olinda/servico/MPV_DadosAbertos/versao/v1/odata$metadata#_MeiosdePagamentosTrimestralDA",
#     "value": [
#         {
#             "datatrimestre": "2024-09-30",
#             "valorPix": 6975429.47,
#             "valorTED": 11180217.68,
#             "valorTEC": 0.0,
#             "valorCheque": 194330.6,
#             "valorBoleto": 2463296.84,
#             "valorDOC": 0.0,
#             "valorCartaoCredito": 662702.46,
#             "valorCartaoDebito": 241932.98,
#             "valorCartaoPrePago": 78531.64,
#             "valorTransIntrabancaria": 6744265.86,
#             "valorConvenios": 961282.82,
#             "valorDebitoDireto": 670954.31,
#             "valorSaques": 526775.87,
#             "quantidadePix": 16546427.27,
#             "quantidadeTED": 203394.26,
#             "quantidadeTEC": 0.0,
#             "quantidadeCheque": 44243.73,
#             "quantidadeBoleto": 1525432.26,
#             "quantidadeDOC": 0.0,
#             "quantidadeCartaoCredito": 5061154.29,
#             "quantidadeCartaoDebito": 4121806.1,
#             "quantidadeCartaoPrePago": 3132432.21,
#             "quantidadeTransIntrabancaria": 771801.22,
#             "quantidadeConvenios": 661708.42,
#             "quantidadeDebitoDireto": 4056085.34,
#             "quantidadeSaques": 664224.81
#         },
#         {
#             "datatrimestre": "2024-06-30",
#             "valorPix": 6284296.05,
#             "valorTED": 10662555.73,
#             "valorTEC": 0.0,
#             "valorCheque": 221553.82,
#             "valorBoleto": 2360420.4,
#             "valorDOC": 0.0,
#             "valorCartaoCredito": 631806.82,
#             "valorCartaoDebito": 239101.56,
#             "valorCartaoPrePago": 77386.79,
#             "valorTransIntrabancaria": 6189022.35,
#             "valorConvenios": 984002.13,
#             "valorDebitoDireto": 585275.47,
#             "valorSaques": 591903.75,
#             "quantidadePix": 15356890.92,
#             "quantidadeTED": 203269.58,
#             "quantidadeTEC": 0.0,
#             "quantidadeCheque": 44981.97,
#             "quantidadeBoleto": 1439104.18,
#             "quantidadeDOC": 0.0,
#             "quantidadeCartaoCredito": 4879670.45,
#             "quantidadeCartaoDebito": 4057958.85,
#             "quantidadeCartaoPrePago": 3046202.02,
#             "quantidadeTransIntrabancaria": 357386.6,
#             "quantidadeConvenios": 679409.28,
#             "quantidadeDebitoDireto": 3320504.73,
#             "quantidadeSaques": 698602.29
#         },
#         {
#             "datatrimestre": "2024-03-31",
#             "valorPix": 5429305.43,
#             "valorTED": 9651625.56,
#             "valorTEC": 925.26,
#             "valorCheque": 190457.25,
#             "valorBoleto": 2248815.45,
#             "valorDOC": 650.8,
#             "valorCartaoCredito": 607470.96,
#             "valorCartaoDebito": 235111.6,
#             "valorCartaoPrePago": 73035.61,
#             "valorTransIntrabancaria": 5396558.52,
#             "valorConvenios": 1082621.22,
#             "valorDebitoDireto": 568515.99,
#             "valorSaques": 522123.87,
#             "quantidadePix": 13575455.59,
#             "quantidadeTED": 203714.16,
#             "quantidadeTEC": 447.19,
#             "quantidadeCheque": 46468.88,
#             "quantidadeBoleto": 1422709.26,
#             "quantidadeDOC": 662.65,
#             "quantidadeCartaoCredito": 4723437.71,
#             "quantidadeCartaoDebito": 3952365.16,
#             "quantidadeCartaoPrePago": 2774237.04,
#             "quantidadeTransIntrabancaria": 321909.52,
#             "quantidadeConvenios": 726660.81,
#             "quantidadeDebitoDireto": 3238627.21,
#             "quantidadeSaques": 683041.3
#         },
#         {
#             "datatrimestre": "2023-12-31",
#             "valorPix": 5300155.0,
#             "valorTED": 10090921.81,
#             "valorTEC": 5787.89,
#             "valorCheque": 221424.78,
#             "valorBoleto": 2317765.95,
#             "valorDOC": 4684.98,
#             "valorCartaoCredito": 630191.34,
#             "valorCartaoDebito": 259057.92,
#             "valorCartaoPrePago": 79592.4,
#             "valorTransIntrabancaria": 5622307.18,
#             "valorConvenios": 992622.17,
#             "valorDebitoDireto": 713985.32,
#             "valorSaques": 644620.62,
#             "quantidadePix": 13045669.89,
#             "quantidadeTED": 226471.15,
#             "quantidadeTEC": 2571.85,
#             "quantidadeCheque": 52101.15,
#             "quantidadeBoleto": 1452479.44,
#             "quantidadeDOC": 4664.79,
#             "quantidadeCartaoCredito": 4813848.35,
#             "quantidadeCartaoDebito": 4238653.32,
#             "quantidadeCartaoPrePago": 2974411.01,
#             "quantidadeTransIntrabancaria": 375748.53,
#             "quantidadeConvenios": 669793.53,
#             "quantidadeDebitoDireto": 3245863.34,
#             "quantidadeSaques": 752444.89
#         },
#         {
#             "datatrimestre": "2023-09-30",
#             "valorPix": 4469529.57,
#             "valorTED": 9960251.89,
#             "valorTEC": 4156.38,
#             "valorCheque": 218121.88,
#             "valorBoleto": 2296882.2,
#             "valorDOC": 10131.89,
#             "valorCartaoCredito": 581902.42,
#             "valorCartaoDebito": 240827.84,
#             "valorCartaoPrePago": 69553.22,
#             "valorTransIntrabancaria": 5432701.79,
#             "valorConvenios": 917960.43,
#             "valorDebitoDireto": 696617.75,
#             "valorSaques": 622701.08,
#             "quantidadePix": 11116947.86,
#             "quantidadeTED": 217717.65,
#             "quantidadeTEC": 1765.08,
#             "quantidadeCheque": 54410.39,
#             "quantidadeBoleto": 1487093.97,
#             "quantidadeDOC": 12613.82,
#             "quantidadeCartaoCredito": 4583771.68,
#             "quantidadeCartaoDebito": 4014361.45,
#             "quantidadeCartaoPrePago": 2677826.63,
#             "quantidadeTransIntrabancaria": 318650.81,
#             "quantidadeConvenios": 706678.69,
#             "quantidadeDebitoDireto": 2791758.96,
#             "quantidadeSaques": 758697.45
#         },
#         {
#             "datatrimestre": "2023-06-30",
#             "valorPix": 3900377.43,
#             "valorTED": 10657463.13,
#             "valorTEC": 4770.74,
#             "valorCheque": 228408.82,
#             "valorBoleto": 2249058.2,
#             "valorDOC": 11258.23,
#             "valorCartaoCredito": 561910.94,
#             "valorCartaoDebito": 238172.21,
#             "valorCartaoPrePago": 63923.28,
#             "valorTransIntrabancaria": 5394386.03,
#             "valorConvenios": 930572.64,
#             "valorDebitoDireto": 657368.51,
#             "valorSaques": 638613.02,
#             "quantidadePix": 9396579.03,
#             "quantidadeTED": 218819.11,
#             "quantidadeTEC": 1992.69,
#             "quantidadeCheque": 56339.37,
#             "quantidadeBoleto": 1494217.09,
#             "quantidadeDOC": 10328.16,
#             "quantidadeCartaoCredito": 4434832.09,
#             "quantidadeCartaoDebito": 3929786.47,
#             "quantidadeCartaoPrePago": 2426618.73,
#             "quantidadeTransIntrabancaria": 278674.95,
#             "quantidadeConvenios": 735860.5,
#             "quantidadeDebitoDireto": 2557307.2,
#             "quantidadeSaques": 778454.0
#         },
#         {
#             "datatrimestre": "2023-03-31",
#             "valorPix": 3447198.28,
#             "valorTED": 9919602.84,
#             "valorTEC": 4535.17,
#             "valorCheque": 240686.19,
#             "valorBoleto": 2211563.4,
#             "valorDOC": 7467.11,
#             "valorCartaoCredito": 535520.44,
#             "valorCartaoDebito": 237175.13,
#             "valorCartaoPrePago": 61169.03,
#             "valorTransIntrabancaria": 5753315.65,
#             "valorConvenios": 968203.13,
#             "valorDebitoDireto": 639081.35,
#             "valorSaques": 528932.43,
#             "quantidadePix": 8116395.5,
#             "quantidadeTED": 228743.99,
#             "quantidadeTEC": 1957.96,
#             "quantidadeCheque": 57830.55,
#             "quantidadeBoleto": 1510864.63,
#             "quantidadeDOC": 7530.9,
#             "quantidadeCartaoCredito": 4189059.28,
#             "quantidadeCartaoDebito": 3835192.13,
#             "quantidadeCartaoPrePago": 2237800.76,
#             "quantidadeTransIntrabancaria": 259476.91,
#             "quantidadeConvenios": 767130.14,
#             "quantidadeDebitoDireto": 2438727.3,
#             "quantidadeSaques": 655963.27
#         },
#         {
#             "datatrimestre": "2022-12-31",
#             "valorPix": 3342913.94,
#             "valorTED": 10382121.63,
#             "valorTEC": 5609.53,
#             "valorCheque": 242259.61,
#             "valorBoleto": 2259674.59,
#             "valorDOC": 9584.63,
#             "valorCartaoCredito": 560765.41,
#             "valorCartaoDebito": 264120.64,
#             "valorCartaoPrePago": 66081.98,
#             "valorTransIntrabancaria": 5511068.32,
#             "valorConvenios": 935377.4,
#             "valorDebitoDireto": 688621.87,
#             "valorSaques": 611825.76,
#             "quantidadePix": 7807165.7,
#             "quantidadeTED": 254289.85,
#             "quantidadeTEC": 2531.94,
#             "quantidadeCheque": 62606.24,
#             "quantidadeBoleto": 1522483.73,
#             "quantidadeDOC": 9871.74,
#             "quantidadeCartaoCredito": 4334758.4,
#             "quantidadeCartaoDebito": 4115443.07,
#             "quantidadeCartaoPrePago": 2303423.64,
#             "quantidadeTransIntrabancaria": 289650.44,
#             "quantidadeConvenios": 737698.14,
#             "quantidadeDebitoDireto": 1936336.01,
#             "quantidadeSaques": 717703.89
#         },
#         {
#             "datatrimestre": "2022-09-30",
#             "valorPix": 2936413.95,
#             "valorTED": 10437763.16,
#             "valorTEC": 3735.46,
#             "valorCheque": 267090.22,
#             "valorBoleto": 2248416.63,
#             "valorDOC": 17106.46,
#             "valorCartaoCredito": 521942.27,
#             "valorCartaoDebito": 243632.86,
#             "valorCartaoPrePago": 55695.33,
#             "valorTransIntrabancaria": 5503514.22,
#             "valorConvenios": 900010.86,
#             "valorDebitoDireto": 728114.38,
#             "valorSaques": 607773.39,
#             "quantidadePix": 6528602.08,
#             "quantidadeTED": 256680.13,
#             "quantidadeTEC": 1677.77,
#             "quantidadeCheque": 68142.99,
#             "quantidadeBoleto": 1538367.11,
#             "quantidadeDOC": 18047.28,
#             "quantidadeCartaoCredito": 4151713.82,
#             "quantidadeCartaoDebito": 3831079.03,
#             "quantidadeCartaoPrePago": 1993806.85,
#             "quantidadeTransIntrabancaria": 274847.98,
#             "quantidadeConvenios": 769091.91,
#             "quantidadeDebitoDireto": 1965282.74,
#             "quantidadeSaques": 725040.4
#         },
#         {
#             "datatrimestre": "2022-06-30",
#             "valorPix": 2543384.4,
#             "valorTED": 10449574.67,
#             "valorTEC": 4786.14,
#             "valorCheque": 271008.09,
#             "valorBoleto": 2210099.22,
#             "valorDOC": 17081.53,
#             "valorCartaoCredito": 501514.74,
#             "valorCartaoDebito": 245563.75,
#             "valorCartaoPrePago": 50925.72,
#             "valorTransIntrabancaria": 5242642.7,
#             "valorConvenios": 903296.33,
#             "valorDebitoDireto": 666854.65,
#             "valorSaques": 708789.71,
#             "quantidadePix": 5447448.22,
#             "quantidadeTED": 254587.79,
#             "quantidadeTEC": 2112.1,
#             "quantidadeCheque": 70141.14,
#             "quantidadeBoleto": 1517092.79,
#             "quantidadeDOC": 17905.1,
#             "quantidadeCartaoCredito": 3974127.06,
#             "quantidadeCartaoDebito": 3778540.37,
#             "quantidadeCartaoPrePago": 1750865.66,
#             "quantidadeTransIntrabancaria": 269502.24,
#             "quantidadeConvenios": 777047.24,
#             "quantidadeDebitoDireto": 2019042.65,
#             "quantidadeSaques": 876660.3
#         },
#         {
#             "datatrimestre": "2022-03-31",
#             "valorPix": 2067826.55,
#             "valorTED": 9507158.34,
#             "valorTEC": 3865.81,
#             "valorCheque": 255455.43,
#             "valorBoleto": 2032317.14,
#             "valorDOC": 11976.36,
#             "valorCartaoCredito": 453292.41,
#             "valorCartaoDebito": 230186.87,
#             "valorCartaoPrePago": 43541.91,
#             "valorTransIntrabancaria": 4789393.75,
#             "valorConvenios": 931426.96,
#             "valorDebitoDireto": 687654.43,
#             "valorSaques": 642753.79,
#             "quantidadePix": 4250023.75,
#             "quantidadeTED": 256893.93,
#             "quantidadeTEC": 1795.35,
#             "quantidadeCheque": 71479.43,
#             "quantidadeBoleto": 1490934.41,
#             "quantidadeDOC": 13194.98,
#             "quantidadeCartaoCredito": 3679415.97,
#             "quantidadeCartaoDebito": 3589968.33,
#             "quantidadeCartaoPrePago": 1507246.16,
#             "quantidadeTransIntrabancaria": 278556.41,
#             "quantidadeConvenios": 789421.14,
#             "quantidadeDebitoDireto": 2049557.88,
#             "quantidadeSaques": 838690.74
#         },
#         {
#             "datatrimestre": "2021-12-31",
#             "valorPix": 1916418.68,
#             "valorTED": 9807293.11,
#             "valorTEC": 5436.19,
#             "valorCheque": 264298.16,
#             "valorBoleto": 2072053.93,
#             "valorDOC": 14166.99,
#             "valorCartaoCredito": 467911.25,
#             "valorCartaoDebito": 257458.3,
#             "valorCartaoPrePago": 42420.5,
#             "valorTransIntrabancaria": 4526131.58,
#             "valorConvenios": 900546.37,
#             "valorDebitoDireto": 603616.19,
#             "valorSaques": 705117.24,
#             "quantidadePix": 3836285.6,
#             "quantidadeTED": 294063.73,
#             "quantidadeTEC": 2678.78,
#             "quantidadeCheque": 77752.86,
#             "quantidadeBoleto": 1497704.81,
#             "quantidadeDOC": 16716.81,
#             "quantidadeCartaoCredito": 3741214.5,
#             "quantidadeCartaoDebito": 3849208.18,
#             "quantidadeCartaoPrePago": 1430826.74,
#             "quantidadeTransIntrabancaria": 226318.22,
#             "quantidadeConvenios": 755053.35,
#             "quantidadeDebitoDireto": 1809992.06,
#             "quantidadeSaques": 919580.38
#         },
#         {
#             "datatrimestre": "2021-09-30",
#             "valorPix": 1556916.22,
#             "valorTED": 9257046.28,
#             "valorTEC": 3684.13,
#             "valorCheque": 271120.34,
#             "valorBoleto": 2001074.0,
#             "valorDOC": 22306.75,
#             "valorCartaoCredito": 399054.11,
#             "valorCartaoDebito": 233970.03,
#             "valorCartaoPrePago": 33731.83,
#             "valorTransIntrabancaria": 4380184.5,
#             "valorConvenios": 808629.48,
#             "valorDebitoDireto": 586001.77,
#             "valorSaques": 673720.99,
#             "quantidadePix": 2863336.94,
#             "quantidadeTED": 296200.34,
#             "quantidadeTEC": 1790.07,
#             "quantidadeCheque": 80110.8,
#             "quantidadeBoleto": 1493638.16,
#             "quantidadeDOC": 27667.96,
#             "quantidadeCartaoCredito": 3311505.26,
#             "quantidadeCartaoDebito": 3526062.88,
#             "quantidadeCartaoPrePago": 1603852.67,
#             "quantidadeTransIntrabancaria": 244008.4,
#             "quantidadeConvenios": 774410.72,
#             "quantidadeDebitoDireto": 1765464.8,
#             "quantidadeSaques": 918141.51
#         },
#         {
#             "datatrimestre": "2021-06-30",
#             "valorPix": 1105735.2,
#             "valorTED": 8566787.27,
#             "valorTEC": 3894.81,
#             "valorCheque": 264944.31,
#             "valorBoleto": 1839452.36,
#             "valorDOC": 23158.84,
#             "valorCartaoCredito": 344999.68,
#             "valorCartaoDebito": 214381.06,
#             "valorCartaoPrePago": 26760.54,
#             "valorTransIntrabancaria": 4171595.71,
#             "valorConvenios": 710453.34,
#             "valorDebitoDireto": 604018.43,
#             "valorSaques": 685333.15,
#             "quantidadePix": 1871563.88,
#             "quantidadeTED": 333917.74,
#             "quantidadeTEC": 1879.38,
#             "quantidadeCheque": 75417.98,
#             "quantidadeBoleto": 1431427.43,
#             "quantidadeDOC": 28659.42,
#             "quantidadeCartaoCredito": 2841992.76,
#             "quantidadeCartaoDebito": 3141691.41,
#             "quantidadeCartaoPrePago": 1264916.88,
#             "quantidadeTransIntrabancaria": 260756.78,
#             "quantidadeConvenios": 733937.43,
#             "quantidadeDebitoDireto": 1709009.85,
#             "quantidadeSaques": 924449.9
#         },
#         {
#             "datatrimestre": "2021-03-31",
#             "valorPix": 625046.52,
#             "valorTED": 7894414.16,
#             "valorTEC": 4352.44,
#             "valorCheque": 253527.92,
#             "valorBoleto": 1769759.68,
#             "valorDOC": 21777.7,
#             "valorCartaoCredito": 310412.13,
#             "valorCartaoDebito": 204752.91,
#             "valorCartaoPrePago": 20327.69,
#             "valorTransIntrabancaria": 3965203.17,
#             "valorConvenios": 728627.48,
#             "valorDebitoDireto": 497283.04,
#             "valorSaques": 673126.6,
#             "quantidadePix": 862337.86,
#             "quantidadeTED": 354171.47,
#             "quantidadeTEC": 2181.17,
#             "quantidadeCheque": 79409.62,
#             "quantidadeBoleto": 1386080.6,
#             "quantidadeDOC": 31687.35,
#             "quantidadeCartaoCredito": 2584404.06,
#             "quantidadeCartaoDebito": 3005004.65,
#             "quantidadeCartaoPrePago": 1016901.48,
#             "quantidadeTransIntrabancaria": 274419.7,
#             "quantidadeConvenios": 766141.92,
#             "quantidadeDebitoDireto": 1704253.83,
#             "quantidadeSaques": 926234.05
#         },
#         {
#             "datatrimestre": "2020-12-31",
#             "valorPix": 149894.91,
#             "valorTED": 8036705.32,
#             "valorTEC": 5137.42,
#             "valorCheque": 278295.37,
#             "valorBoleto": 1919100.6,
#             "valorDOC": 38705.14,
#             "valorCartaoCredito": 332987.17,
#             "valorCartaoDebito": 258471.49,
#             "valorCartaoPrePago": 19923.51,
#             "valorTransIntrabancaria": 4095052.12,
#             "valorConvenios": 719279.59,
#             "valorDebitoDireto": 456624.59,
#             "valorSaques": 765824.47,
#             "quantidadePix": 176206.65,
#             "quantidadeTED": 574879.66,
#             "quantidadeTEC": 2549.74,
#             "quantidadeCheque": 91594.82,
#             "quantidadeBoleto": 1472868.82,
#             "quantidadeDOC": 58634.44,
#             "quantidadeCartaoCredito": 2672666.45,
#             "quantidadeCartaoDebito": 3483509.4,
#             "quantidadeCartaoPrePago": 1056946.56,
#             "quantidadeTransIntrabancaria": 348828.24,
#             "quantidadeConvenios": 750242.75,
#             "quantidadeDebitoDireto": 1700531.57,
#             "quantidadeSaques": 1084574.42
#         },
#         {
#             "datatrimestre": "2020-09-30",
#             "valorPix": 0.0,
#             "valorTED": 7503982.24,
#             "valorTEC": 4159.6,
#             "valorCheque": 259334.88,
#             "valorBoleto": 1959819.72,
#             "valorDOC": 52156.84,
#             "valorCartaoCredito": 279176.98,
#             "valorCartaoDebito": 228771.89,
#             "valorCartaoPrePago": 14809.51,
#             "valorTransIntrabancaria": 3864293.29,
#             "valorConvenios": 620034.56,
#             "valorDebitoDireto": 415448.62,
#             "valorSaques": 723099.8,
#             "quantidadePix": 0.0,
#             "quantidadeTED": 541157.7,
#             "quantidadeTEC": 2024.38,
#             "quantidadeCheque": 86966.27,
#             "quantidadeBoleto": 1389215.55,
#             "quantidadeDOC": 74377.91,
#             "quantidadeCartaoCredito": 2280096.07,
#             "quantidadeCartaoDebito": 2957015.55,
#             "quantidadeCartaoPrePago": 795301.85,
#             "quantidadeTransIntrabancaria": 338018.29,
#             "quantidadeConvenios": 776086.02,
#             "quantidadeDebitoDireto": 1623252.19,
#             "quantidadeSaques": 1009737.66
#         },
#         {
#             "datatrimestre": "2020-06-30",
#             "valorPix": 0.0,
#             "valorTED": 6267004.16,
#             "valorTEC": 4647.32,
#             "valorCheque": 237873.12,
#             "valorBoleto": 1366623.21,
#             "valorDOC": 50881.15,
#             "valorCartaoCredito": 224389.54,
#             "valorCartaoDebito": 152246.79,
#             "valorCartaoPrePago": 8969.46,
#             "valorTransIntrabancaria": 3619039.33,
#             "valorConvenios": 480987.36,
#             "valorDebitoDireto": 440102.05,
#             "valorSaques": 663932.32,
#             "quantidadePix": 0.0,
#             "quantidadeTED": 381386.51,
#             "quantidadeTEC": 2267.31,
#             "quantidadeCheque": 85355.07,
#             "quantidadeBoleto": 1256812.05,
#             "quantidadeDOC": 73763.72,
#             "quantidadeCartaoCredito": 1907929.12,
#             "quantidadeCartaoDebito": 2259584.47,
#             "quantidadeCartaoPrePago": 533545.65,
#             "quantidadeTransIntrabancaria": 303062.51,
#             "quantidadeConvenios": 752351.43,
#             "quantidadeDebitoDireto": 1542581.41,
#             "quantidadeSaques": 934644.94
#         },
#         {
#             "datatrimestre": "2020-03-31",
#             "valorPix": 0.0,
#             "valorTED": 6652135.13,
#             "valorTEC": 4829.56,
#             "valorCheque": 318844.92,
#             "valorBoleto": 1526486.76,
#             "valorDOC": 30628.55,
#             "valorCartaoCredito": 275659.09,
#             "valorCartaoDebito": 171399.49,
#             "valorCartaoPrePago": 8700.25,
#             "valorTransIntrabancaria": 4138724.78,
#             "valorConvenios": 700965.21,
#             "valorDebitoDireto": 481940.35,
#             "valorSaques": 719800.78,
#             "quantidadePix": 0.0,
#             "quantidadeTED": 329386.2,
#             "quantidadeTEC": 2416.48,
#             "quantidadeCheque": 115237.83,
#             "quantidadeBoleto": 1184510.67,
#             "quantidadeDOC": 43503.55,
#             "quantidadeCartaoCredito": 2492783.1,
#             "quantidadeCartaoDebito": 2757914.17,
#             "quantidadeCartaoPrePago": 577500.51,
#             "quantidadeTransIntrabancaria": 293996.77,
#             "quantidadeConvenios": 860763.75,
#             "quantidadeDebitoDireto": 1522644.97,
#             "quantidadeSaques": 1034924.99
#         },
#         {
#             "datatrimestre": "2019-12-31",
#             "valorPix": 0.0,
#             "valorTED": 6560042.73,
#             "valorTEC": 6343.77,
#             "valorCheque": 372693.66,
#             "valorBoleto": 1579497.09,
#             "valorDOC": 37728.79,
#             "valorCartaoCredito": 302888.19,
#             "valorCartaoDebito": 193673.01,
#             "valorCartaoPrePago": 8940.68,
#             "valorTransIntrabancaria": 3774510.81,
#             "valorConvenios": 709453.52,
#             "valorDebitoDireto": 1179392.45,
#             "valorSaques": 866834.6,
#             "quantidadePix": 0.0,
#             "quantidadeTED": 324349.9,
#             "quantidadeTEC": 3185.05,
#             "quantidadeCheque": 134725.84,
#             "quantidadeBoleto": 1190397.8,
#             "quantidadeDOC": 51756.51,
#             "quantidadeCartaoCredito": 2681083.06,
#             "quantidadeCartaoDebito": 3102432.97,
#             "quantidadeCartaoPrePago": 159510.21,
#             "quantidadeTransIntrabancaria": 365515.57,
#             "quantidadeConvenios": 786763.01,
#             "quantidadeDebitoDireto": 1459193.74,
#             "quantidadeSaques": 1237366.49
#         },
#         {
#             "datatrimestre": "2019-09-30",
#             "valorPix": 0.0,
#             "valorTED": 6285701.44,
#             "valorTEC": 5469.66,
#             "valorCheque": 385735.21,
#             "valorBoleto": 1484836.27,
#             "valorDOC": 39652.79,
#             "valorCartaoCredito": 272414.67,
#             "valorCartaoDebito": 164735.63,
#             "valorCartaoPrePago": 7803.22,
#             "valorTransIntrabancaria": 3378209.53,
#             "valorConvenios": 713191.48,
#             "valorDebitoDireto": 1172377.68,
#             "valorSaques": 825956.86,
#             "quantidadePix": 0.0,
#             "quantidadeTED": 276656.06,
#             "quantidadeTEC": 2751.37,
#             "quantidadeCheque": 138322.67,
#             "quantidadeBoleto": 1155112.73,
#             "quantidadeDOC": 53387.74,
#             "quantidadeCartaoCredito": 2516328.04,
#             "quantidadeCartaoDebito": 2749305.82,
#             "quantidadeCartaoPrePago": 109323.89,
#             "quantidadeTransIntrabancaria": 347495.65,
#             "quantidadeConvenios": 864138.87,
#             "quantidadeDebitoDireto": 1514404.88,
#             "quantidadeSaques": 1150223.87
#         },
#         {
#             "datatrimestre": "2019-06-30",
#             "valorPix": 0.0,
#             "valorTED": 5700739.79,
#             "valorTEC": 5506.27,
#             "valorCheque": 388525.47,
#             "valorBoleto": 1409618.75,
#             "valorDOC": 34716.55,
#             "valorCartaoCredito": 253161.38,
#             "valorCartaoDebito": 153747.19,
#             "valorCartaoPrePago": 6572.85,
#             "valorTransIntrabancaria": 3090737.62,
#             "valorConvenios": 677754.24,
#             "valorDebitoDireto": 1009756.11,
#             "valorSaques": 810157.4,
#             "quantidadePix": 0.0,
#             "quantidadeTED": 232644.16,
#             "quantidadeTEC": 2847.69,
#             "quantidadeCheque": 138158.92,
#             "quantidadeBoleto": 1076813.11,
#             "quantidadeDOC": 47739.37,
#             "quantidadeCartaoCredito": 2324477.29,
#             "quantidadeCartaoDebito": 2524775.4,
#             "quantidadeCartaoPrePago": 77904.49,
#             "quantidadeTransIntrabancaria": 331095.31,
#             "quantidadeConvenios": 811802.76,
#             "quantidadeDebitoDireto": 1418749.18,
#             "quantidadeSaques": 1114642.78
#         },
#         {
#             "datatrimestre": "2019-03-31",
#             "valorPix": 0.0,
#             "valorTED": 5039380.73,
#             "valorTEC": 4794.82,
#             "valorCheque": 375916.28,
#             "valorBoleto": 1468066.32,
#             "valorDOC": 35812.8,
#             "valorCartaoCredito": 235435.49,
#             "valorCartaoDebito": 151764.67,
#             "valorCartaoPrePago": 5019.16,
#             "valorTransIntrabancaria": 2977140.95,
#             "valorConvenios": 922161.77,
#             "valorDebitoDireto": 1096747.51,
#             "valorSaques": 807704.63,
#             "quantidadePix": 0.0,
#             "quantidadeTED": 199727.26,
#             "quantidadeTEC": 2587.9,
#             "quantidadeCheque": 139621.22,
#             "quantidadeBoleto": 1020583.81,
#             "quantidadeDOC": 52449.83,
#             "quantidadeCartaoCredito": 2081348.82,
#             "quantidadeCartaoDebito": 2471245.21,
#             "quantidadeCartaoPrePago": 58847.58,
#             "quantidadeTransIntrabancaria": 307650.07,
#             "quantidadeConvenios": 913784.42,
#             "quantidadeDebitoDireto": 1381466.73,
#             "quantidadeSaques": 1103906.31
#         }
#     ]
# }
